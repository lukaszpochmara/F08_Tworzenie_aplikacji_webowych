# %%
import pandas as pd
df = pd.read_csv("cleaned_data.csv")

print(df.select_dtypes('object').columns)

def show_categorical_distributions(df):
    cat_cols = df.select_dtypes('object').columns
    for col in cat_cols:          # <-- loop over columns
        print(f"**{col}**")
        print(df[col].value_counts())

show_categorical_distributions(df)
# Out:
# Index(['name', 'sex', 'ticket', 'cabin', 'embarked', 'boat', 'home.dest'], dtype='object')
# **name**
# name
# Connolly, Miss. Kate             2
# Kelly, Mr. James                 2
# Allen, Miss. Elisabeth Walton    1
# Ilmakangas, Miss. Ida Livija     1
# Ilieff, Mr. Ylio                 1
#                                 ..
# Hart, Miss. Eva Miriam           1
# Harris, Mr. Walter               1
# Harris, Mr. George               1
# Harper, Rev. John                1
# Zimmerman, Mr. Leo               1
# Name: count, Length: 1307, dtype: int64
# **sex**
# sex
# male      843
# female    466
# Name: count, dtype: int64
# **ticket**
# ticket
# CA. 2343    11
# 1601         8
# CA 2144      8
# PC 17608     7
# 347077       7
#             ..
# 373450       1
# 2223         1
# 350046       1
# 3101281      1
# 315082       1
# Name: count, Length: 929, dtype: int64
# **cabin**
# cabin
# C23 C25 C27        6
# G6                 5
# B57 B59 B63 B66    5
# F4                 4
# F33                4
#                   ..
# C132               1
# E60                1
# B52 B54 B56        1
# C49                1
# F38                1
# Name: count, Length: 186, dtype: int64
# **embarked**
# embarked
# S    914
# C    270
# Q    123
# Name: count, dtype: int64
# **boat**
# boat
# 13         39
# C          38
# 15         37
# 14         33
# 4          31
# 10         29
# 5          27
# 3          26
# 9          25
# 11         25
# 16         23
# 8          23
# 7          23
# D          20
# 6          20
# 12         19
# 2          13
# A          11
# B           9
# 1           5
# 5 7         2
# C D         2
# 13 15       2
# 5 9         1
# 8 10        1
# 13 15 B     1
# 15 16       1
# Name: count, dtype: int64
# **home.dest**
# home.dest
# New York, NY                                    64
# London                                          14
# Montreal, PQ                                    10
# Paris, France                                    9
# Cornwall / Akron, OH                             9
#                                                 ..
# Chelsea, London                                  1
# Harrow-on-the-Hill, Middlesex                    1
# Copenhagen, Denmark                              1
# Guernsey / Montclair, NJ and/or Toledo, Ohio     1
# Antwerp, Belgium / Stanton, OH                   1
# Name: count, Length: 369, dtype: int64

# %%
df["boat"].value_counts()
# Out:
# boat
# 13         39
# C          38
# 15         37
# 14         33
# 4          31
# 10         29
# 5          27
# 3          26
# 9          25
# 11         25
# 16         23
# 8          23
# 7          23
# D          20
# 6          20
# 12         19
# 2          13
# A          11
# B           9
# 1           5
# 5 7         2
# C D         2
# 13 15       2
# 5 9         1
# 8 10        1
# 13 15 B     1
# 15 16       1
# Name: count, dtype: int64

# %%
df["sex"].value_counts()
# Out:
# sex
# male      843
# female    466
# Name: count, dtype: int64

# %%
df["sex"].value_counts()

df_1 = df[["sex", "boat"]]
print(df_1)
df_2 = pd.get_dummies(df_1)
df_2
# Out:
#          sex boat
# 0     female    2
# 1       male   11
# 2     female  NaN
# 3       male  NaN
# 4     female  NaN
# ...      ...  ...
# 1304  female  NaN
# 1305  female  NaN
# 1306    male  NaN
# 1307    male  NaN
# 1308    male  NaN
#
# [1309 rows x 2 columns]
#       sex_female  sex_male  boat_1  boat_10  boat_11  boat_12  boat_13  \
# 0           True     False   False    False    False    False    False
# 1          False      True   False    False     True    False    False
# 2           True     False   False    False    False    False    False
# 3          False      True   False    False    False    False    False
# 4           True     False   False    False    False    False    False
# ...          ...       ...     ...      ...      ...      ...      ...
# 1304        True     False   False    False    False    False    False
# 1305        True     False   False    False    False    False    False
# 1306       False      True   False    False    False    False    False
# 1307       False      True   False    False    False    False    False
# 1308       False      True   False    False    False    False    False
#
#       boat_13 15  boat_13 15 B  boat_14  ...  boat_6  boat_7  boat_8  \
# 0          False         False    False  ...   False   False   False
# 1          False         False    False  ...   False   False   False
# 2          False         False    False  ...   False   False   False
# 3          False         False    False  ...   False   False   False
# 4          False         False    False  ...   False   False   False
# ...          ...           ...      ...  ...     ...     ...     ...
# 1304       False         False    False  ...   False   False   False
# 1305       False         False    False  ...   False   False   False
# 1306       False         False    False  ...   False   False   False
# 1307       False         False    False  ...   False   False   False
# 1308       False         False    False  ...   False   False   False
#
#       boat_8 10  boat_9  boat_A  boat_B  boat_C  boat_C D  boat_D
# 0         False   False   False   False   False     False   False
# 1         False   False   False   False   False     False   False
# 2         False   False   False   False   False     False   False
# 3         False   False   False   False   False     False   False
# 4         False   False   False   False   False     False   False
# ...         ...     ...     ...     ...     ...       ...     ...
# 1304      False   False   False   False   False     False   False
# 1305      False   False   False   False   False     False   False
# 1306      False   False   False   False   False     False   False
# 1307      False   False   False   False   False     False   False
# 1308      False   False   False   False   False     False   False
#
# [1309 rows x 29 columns]

# %%
df_2["boat_1"].value_counts()
# Out:
# boat_1
# False    1304
# True        5
# Name: count, dtype: int64
